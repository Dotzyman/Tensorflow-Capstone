# %%
#import needed libraries
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt

# %% [markdown]
# DATA CLEANING

# %%
df = pd.read_excel(r"C:\Users\user\Documents\HAMOYE DATA SCIENCE\PREMIER PROJECT (Tensorflow group)\Foreign_Exchange_Rates.xlsx")

# %%
df
# Out:
#       Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$ EURO AREA - EURO/US$  \
# 0     2000-01-03                            1.5172               0.9847
# 1     2000-01-04                            1.5239                 0.97
# 2     2000-01-05                            1.5267               0.9676
# 3     2000-01-06                            1.5291               0.9686
# 4     2000-01-07                            1.5272               0.9714
# ...          ...                               ...                  ...
# 5212  2019-12-25                                ND                   ND
# 5213  2019-12-26                            1.4411               0.9007
# 5214  2019-12-27                            1.4331               0.8949
# 5215  2019-12-30                            1.4278               0.8915
# 5216  2019-12-31                            1.4225               0.8907
#
#      NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                                 1.9033
# ...

# %%
df.replace('ND', np.nan, inplace=True)

# %%
df
# Out:
#       Time Serie  AUSTRALIA - AUSTRALIAN DOLLAR/US$  EURO AREA - EURO/US$  \
# 0     2000-01-03                             1.5172                0.9847
# 1     2000-01-04                             1.5239                0.9700
# 2     2000-01-05                             1.5267                0.9676
# 3     2000-01-06                             1.5291                0.9686
# 4     2000-01-07                             1.5272                0.9714
# ...          ...                                ...                   ...
# 5212  2019-12-25                                NaN                   NaN
# 5213  2019-12-26                             1.4411                0.9007
# 5214  2019-12-27                             1.4331                0.8949
# 5215  2019-12-30                             1.4278                0.8915
# 5216  2019-12-31                             1.4225                0.8907
#
#       NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# ...

# %%
#Checking for missing data
df.isnull().sum()
# Out:
# Time Serie                                     0
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            198
# EURO AREA - EURO/US$                         198
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          198
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    198
# BRAZIL - REAL/US$                            198
# CANADA - CANADIAN DOLLAR/US$                 198
# CHINA - YUAN/US$                             197
# HONG KONG - HONG KONG DOLLAR/US$             198
# INDIA - INDIAN RUPEE/US$                     199
# KOREA - WON/US$                              198
# MEXICO - MEXICAN PESO/US$                    198
# SOUTH AFRICA - RAND/US$                      198
# SINGAPORE - SINGAPORE DOLLAR/US$             198
# DENMARK - DANISH KRONE/US$                   198
# JAPAN - YEN/US$                              198
# MALAYSIA - RINGGIT/US$                       198
# NORWAY - NORWEGIAN KRONE/US$                 198
# SWEDEN - KRONA/US$                           198
# ...

# %% [markdown]
# Data contains some missing values

# %%
#Handling missing data by filling with preceding values 
df.ffill (axis= 'rows', inplace=True)

# %%
#Checking for outliers using boxplot
df.plot(kind = "box", figsize=(15,4) )
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the boxplot, we can see the data has no outlier

# %%
#Setting to Standardized Pandas date
df['Time Serie'] = pd.to_datetime(df['Time Serie'])

# %%
#Cleaned Data
df
# Out:
#      Time Serie  AUSTRALIA - AUSTRALIAN DOLLAR/US$  EURO AREA - EURO/US$  \
# 0    2000-01-03                             1.5172                0.9847
# 1    2000-01-04                             1.5239                0.9700
# 2    2000-01-05                             1.5267                0.9676
# 3    2000-01-06                             1.5291                0.9686
# 4    2000-01-07                             1.5272                0.9714
# ...         ...                                ...                   ...
# 5212 2019-12-25                             1.4445                0.9022
# 5213 2019-12-26                             1.4411                0.9007
# 5214 2019-12-27                             1.4331                0.8949
# 5215 2019-12-30                             1.4278                0.8915
# 5216 2019-12-31                             1.4225                0.8907
#
#       NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                                  1.9033
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
#Data information and description
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5217 entries, 0 to 5216
# Data columns (total 23 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Time Serie                                 5217 non-null   datetime64[ns]
#  1   AUSTRALIA - AUSTRALIAN DOLLAR/US$          5217 non-null   float64
#  2   EURO AREA - EURO/US$                       5217 non-null   float64
#  3   NEW ZEALAND - NEW ZELAND DOLLAR/US$        5217 non-null   float64
#  4   UNITED KINGDOM - UNITED KINGDOM POUND/US$  5217 non-null   float64
#  5   BRAZIL - REAL/US$                          5217 non-null   float64
#  6   CANADA - CANADIAN DOLLAR/US$               5217 non-null   float64
#  7   CHINA - YUAN/US$                           5217 non-null   float64
#  8   HONG KONG - HONG KONG DOLLAR/US$           5217 non-null   float64
# ...

# %%
#Checking for Duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data has no duplicate

# %%
# shape of the data
df.shape
# Out:
# (5217, 23)

# %% [markdown]
# Data contains 5217 rows and 28 columns

# %%
#Checking for missing data
df.isnull().sum()
# Out:
# Time Serie                                   0
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            0
# EURO AREA - EURO/US$                         0
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          0
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    0
# BRAZIL - REAL/US$                            0
# CANADA - CANADIAN DOLLAR/US$                 0
# CHINA - YUAN/US$                             0
# HONG KONG - HONG KONG DOLLAR/US$             0
# INDIA - INDIAN RUPEE/US$                     0
# KOREA - WON/US$                              0
# MEXICO - MEXICAN PESO/US$                    0
# SOUTH AFRICA - RAND/US$                      0
# SINGAPORE - SINGAPORE DOLLAR/US$             0
# DENMARK - DANISH KRONE/US$                   0
# JAPAN - YEN/US$                              0
# MALAYSIA - RINGGIT/US$                       0
# NORWAY - NORWEGIAN KRONE/US$                 0
# SWEDEN - KRONA/US$                           0
# SRI LANKA - SRI LANKAN RUPEE/US$             0
# ...

# %% [markdown]
# Cleaned data have no missing data

# %%
#Information on Foreign exchange rate of China-Yuan/US$
df['CHINA - YUAN/US$'].describe()
# Out:
# count    5217.000000
# mean        7.199286
# std         0.819876
# min         6.040200
# 25%         6.475800
# 50%         6.859700
# 75%         8.276500
# max         8.280000
# Name: CHINA - YUAN/US$, dtype: float64

# %% [markdown]
# The minimum rate was recorded to be 6.04, and maximum at 8.28

# %% [markdown]
# TIME SERIES DATA

# %%
#Data to use for analysis
Timeseries_data = df[['Time Serie', 'CHINA - YUAN/US$']].copy()

# %%
Timeseries_data
# Out:
#      Time Serie  CHINA - YUAN/US$
# 0    2000-01-03            8.2798
# 1    2000-01-04            8.2799
# 2    2000-01-05            8.2798
# 3    2000-01-06            8.2797
# 4    2000-01-07            8.2794
# ...         ...               ...
# 5212 2019-12-25            7.0064
# 5213 2019-12-26            6.9949
# 5214 2019-12-27            6.9954
# 5215 2019-12-30            6.9864
# 5216 2019-12-31            6.9618
#
# [5217 rows x 2 columns]

# %%
#Checking for outliers in the Time series data
Timeseries_data.plot(kind = "box", figsize=(8,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see the data has no outlier

# %%
#Trend of China-Yuan/US$ over time 
Timeseries_data.plot.line(x = 'Time Serie',  y = 'CHINA - YUAN/US$')
# Out:
# <AxesSubplot:xlabel='Time Serie'>

# %% [markdown]
# Trend of China-yuan/US$ over the years
